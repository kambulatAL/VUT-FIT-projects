# %%
#!/usr/bin/python3.10
# coding=utf-8
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import contextily as ctx
import sklearn.cluster as clstr
import numpy as np
from shapely.geometry import Point,box
from matplotlib import cm
from matplotlib.colors import Normalize

# %%
def reformat_data(df: pd.DataFrame) -> pd.DataFrame:
    new_df = df.copy()

    new_df["p2a"] = pd.to_datetime(new_df["p2a"])
    new_df.drop_duplicates(subset=['p1'], inplace=True)

    # not_category = ["p1", "p2a", "p2b", "p13a", "p13b", "p13c", "p14", "p34", "p37", "p53", "date"]
    
    # for col in new_df.columns:
    #     if new_df[col].dtype == 'int64':
    #         new_df[new_df[col] == -1] = np.nan
    #     elif new_df[col].dtype == 'object':
    #         new_df[new_df[col] == ""] = np.nan
    #     if col not in not_category:
    #         new_df[col] = new_df[col].astype('category')
        

    # float_cols = ["p37", "a", "b", "d", "e", "f", "g", "o", "n", "r", "s"]
    # for col in float_cols:
    #     new_df[col] = new_df[col].astype(str).str.replace(',', '.')
    #     new_df[col] = pd.to_numeric(new_df[col], errors='coerce')
    #     # new_df[col] = new_df[col].astype(float)
    
    new_df.dropna(subset=['e','d'],inplace=True)
    new_df = new_df.dropna(axis=1)
    return new_df

# %%
def make_geo(df: pd.DataFrame) -> geopandas.GeoDataFrame:
    """ Konvertovani dataframe do geopandas.GeoDataFrame se spravnym kodovani"""
    new_df = reformat_data(df).query('region == "JHM"')
    # # new_df.dropna(axis=1,inplace=True)
    # new_df = new_df.reset_index(drop=True)
    # gdf = geopandas.GeoDataFrame(new_df, geometry=geopandas.points_from_xy(new_df['d'],new_df['e']),crs='epsg:4156')
    # return gdf
    
    # Convert 'd' and 'e' columns to a GeoDataFrame with Point geometries
    geometry = [Point(xy) for xy in zip(new_df['d'], new_df['e'])]
    
    # Create a GeoDataFrame
    gdf = geopandas.GeoDataFrame(new_df, geometry=geometry, crs='EPSG:5514')
    

    return gdf

# %%
gdf = make_geo(pd.read_pickle("accidents.pkl.gz"))

# %%
# int_cols = [col for col in gdf.columns if gdf[col].dtype == 'int64']
gdf.info()
gdf.crs
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 50098 entries, 0 to 6375
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   p1            50098 non-null  int64
#  1   p36           50098 non-null  int64
#  2   p2a           50098 non-null  datetime64[ns]
#  3   weekday(p2a)  50098 non-null  int64
#  4   p2b           50098 non-null  int64
#  5   p6            50098 non-null  int64
#  6   p7            50098 non-null  int64
#  7   p8            50098 non-null  int64
#  8   p9            50098 non-null  int64
#  9   p10           50098 non-null  int64
#  10  p11           50098 non-null  int64
#  11  p12           50098 non-null  int64
#  12  p13a          50098 non-null  int64
#  13  p13b          50098 non-null  int64
#  14  p13c          50098 non-null  int64
#  15  p14           50098 non-null  int64
#  16  p21           50098 non-null  int64
#  17  p22           50098 non-null  int64
#  18  p23           50098 non-null  int64
#  19  p24           50098 non-null  int64
#  20  p27           50098 non-null  int64
#  21  p28           50098 non-null  int64
#  22  p34           50098 non-null  int64
#  23  p35           50098 non-null  int64
#  24  p44           50098 non-null  int64
#  25  p53           50098 non-null  int64
#  26  d             50098 non-null  float64
#  27  e             50098 non-null  float64
#  28  p5a           50098 non-null  int64
#  29  region        50098 non-null  object
#  30  date          50098 non-null  datetime64[ns]
#  31  geometry      50098 non-null  geometry
# dtypes: datetime64[ns](2), float64(2), geometry(1), int64(26), object(1)
# memory usage: 12.6+ MB
# <Projected CRS: EPSG:5514>
# Name: S-JTSK / Krovak East North
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Czechia; Slovakia.
# - bounds: (12.09, 47.73, 22.56, 51.06)
# Coordinate Operation:
# - name: Krovak East North (Greenwich)
# - method: Krovak (North Orientated)
# Datum: System of the Unified Trigonometrical Cadastral Network
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
def plot_geo(gdf: geopandas.GeoDataFrame, fig_location: str = None,
             show_figure: bool = False):
    """ Vykresleni grafu s nehodami  """
   
    # create a bounding box to contraint drawing and points
    bounds = [-935719.38, -1244158.89,-418597.43, -911041.21]
    bounding_box = box(*bounds)

    # filter points within the bounding box
    filtered = gdf[gdf.geometry.within(bounding_box)]

    condition_2021 = (filtered['p10'] == 4) & (filtered['date'].dt.year == 2021)
    condition_2022 = (filtered['p10'] == 4) & (filtered['date'].dt.year == 2022)

    fig, ax = plt.subplots(1, 2, figsize=(15, 15))

    # plot for 2021
    filtered[condition_2021].plot(ax=ax[0], color='blue', markersize=5, alpha=0.6, aspect=1)
    ax[0].set_title('Nehody zaviněné zvěří v JHM kraji roce 2021')

    # plot for 2022
    filtered[condition_2022].plot(ax=ax[1], color='blue', markersize=5, alpha=0.6, aspect=1)
    ax[1].set_title('Nehody zaviněné zvěří v JHM kraji roce 2022')
   
    for axis in ax:
        ctx.add_basemap(axis, crs=gdf.crs.to_string(), source=ctx.providers.OpenStreetMap.Mapnik, alpha=0.9,zoom=10)
        axis.set_axis_off()

    # Save or show the figure
    if fig_location:
        plt.savefig(fig_location)
    if show_figure:
        plt.show()

# %%
plot_geo(gdf, "geo1.png", True)

# %%
def plot_cluster(gdf: geopandas.GeoDataFrame, fig_location: str = None,
                 show_figure: bool = False):
    """ Vykresleni grafu s lokalitou vsech nehod v kraji shlukovanych do clusteru """
    
    # create a bounding box to contraint drawing and points
    bounds = [-935719.38, -1244158.89,-418597.43, -911041.21]
    bounding_box = box(*bounds)

    # filter points within the bounding box
    filtered = gdf[gdf.geometry.within(bounding_box)]
    filtered = filtered[filtered['p11'] >= 4]

    # clusterize data using k-means ML algorithm
    filtered['cluster_labels'] = clstr.KMeans(n_clusters=12, random_state=42, n_init="auto").fit_predict(filtered[['d','e']])
    
    # calculate convex hulls for each cluster
    convex_hulls = filtered.groupby('cluster_labels')['geometry'].apply(lambda x: x.unary_union.convex_hull).reset_index()

    # create polygons for emphasizing clusters' areas with color
    polygons = geopandas.GeoDataFrame(geometry=convex_hulls['geometry'], crs=gdf.crs)

    fig, ax = plt.subplots(figsize=(13, 13))
    
    # plot polygons based on convex hulls
    polygons.plot(ax=ax, color='grey', alpha=0.3)
    
    filtered.plot(ax=ax,column='cluster_labels',cmap='plasma', markersize=5)

    # create a separate ScalarMappable for the colorbar
    cluster_counts = filtered['cluster_labels'].value_counts()
    
    norm = Normalize(vmin=cluster_counts.min(), vmax=cluster_counts.max())
    cmap = cm.ScalarMappable(norm=norm, cmap='plasma')
    cmap.set_array([])
    
    # create a colorbar based on the ScalarMappable
    cbar = plt.colorbar(cmap, ax=ax, orientation='horizontal', pad=0.02, label='Počet nehod v úseku')

    # add basemap to show a terrain
    ctx.add_basemap(ax, crs=gdf.crs.to_string(), source=ctx.providers.OpenStreetMap.Mapnik, alpha=0.9,zoom=10)
    ax.set_axis_off()
    ax.set_title('Nehody v JHM kraji s významnou měrou alkoholu')
    
    # save or show the figure
    if fig_location:
        plt.savefig(fig_location)
    if show_figure:
        plt.show()

# %%
plot_cluster(gdf,'geo2.png',True)

# %%
# if __name__ == "__main__":
#     # zde muzete delat libovolne modifikace
#     gdf = make_geo(pd.read_pickle("accidents.pkl.gz"))
#     plot_geo(gdf, "geo1.png", True)
#     plot_cluster(gdf, "geo2.png", True)
